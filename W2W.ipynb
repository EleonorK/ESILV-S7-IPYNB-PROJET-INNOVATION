# %%
#pip install Pillow
import pandas as pd

# %%
data = pd.read_csv("all_content.csv")
data
# Out:
#       annee                                                nom  \
# 0      2022                                     [' Mercredi ']
# 1      2022                                         [' 1899 ']
# 2      2010                             [' The Walking Dead ']
# 3      2018                                     [' Manifest ']
# 4      2022  [' Le Cabinet de curiosités de Guillermo del T...
# ...     ...                                                ...
# 8992   2015                              [' Owarimonogatari ']
# 8993   2008                                         [' Flow ']
# 8994   2021                         [' Hetalia: World Stars ']
# 8995   2017               [" Fate/Stay Night: Heaven's Feel "]
# 8996   2018                                      [' Born To ']
#
#                                                 acteurs  \
# 0     ['"JennaOrtega","GwendolineChristie","PercyHyn...
# 1     ['"EmilyBeecham","AndreasPietschmann","Aneurin...
# ...

# %%
for k in range (len(data)):
    
    data["genres"][k]=data["genres"][k].replace("'","")
    data["genres"][k]=data["genres"][k].replace('"',"")
    data["genres"][k]=data["genres"][k].replace("[","")
    data["genres"][k]=data["genres"][k].replace("]","")

data
# Out:
# /var/folders/5g/3_n1b4wj6rd2cr07gfh2bv6w0000gn/T/ipykernel_25466/1148922871.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["genres"][k]=data["genres"][k].replace("'","")
# /var/folders/5g/3_n1b4wj6rd2cr07gfh2bv6w0000gn/T/ipykernel_25466/1148922871.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["genres"][k]=data["genres"][k].replace('"',"")
# /var/folders/5g/3_n1b4wj6rd2cr07gfh2bv6w0000gn/T/ipykernel_25466/1148922871.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
for k in range(len(data)):
    data.genres[k]=data.genres[k].split(",")
    
data
# Out:
# /var/folders/5g/3_n1b4wj6rd2cr07gfh2bv6w0000gn/T/ipykernel_25466/4171613296.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.genres[k]=data.genres[k].split(",")
#       annee                                                nom  \
# 0      2022                                     [' Mercredi ']
# 1      2022                                         [' 1899 ']
# 2      2010                             [' The Walking Dead ']
# 3      2018                                     [' Manifest ']
# 4      2022  [' Le Cabinet de curiosités de Guillermo del T...
# ...     ...                                                ...
# 8992   2015                              [' Owarimonogatari ']
# 8993   2008                                         [' Flow ']
# ...

# %%
for k in range (len(data)):
    
    data["acteurs"][k]=data["acteurs"][k].replace("'","")
    data["acteurs"][k]=data["acteurs"][k].replace('"',"")
    data["acteurs"][k]=data["acteurs"][k].replace("[","")
    data["acteurs"][k]=data["acteurs"][k].replace("]","")

data
# Out:
# /var/folders/5g/3_n1b4wj6rd2cr07gfh2bv6w0000gn/T/ipykernel_25466/3821331633.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["acteurs"][k]=data["acteurs"][k].replace("'","")
# /var/folders/5g/3_n1b4wj6rd2cr07gfh2bv6w0000gn/T/ipykernel_25466/3821331633.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["acteurs"][k]=data["acteurs"][k].replace('"',"")
# /var/folders/5g/3_n1b4wj6rd2cr07gfh2bv6w0000gn/T/ipykernel_25466/3821331633.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
for k in range(len(data)):
    data.acteurs[k]=data.acteurs[k].split(",")
    
data
# Out:
# /var/folders/5g/3_n1b4wj6rd2cr07gfh2bv6w0000gn/T/ipykernel_25466/1885357814.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.acteurs[k]=data.acteurs[k].split(",")
#       annee                                                nom  \
# 0      2022                                     [' Mercredi ']
# 1      2022                                         [' 1899 ']
# 2      2010                             [' The Walking Dead ']
# 3      2018                                     [' Manifest ']
# 4      2022  [' Le Cabinet de curiosités de Guillermo del T...
# ...     ...                                                ...
# 8992   2015                              [' Owarimonogatari ']
# 8993   2008                                         [' Flow ']
# ...

# %%
for k in range (len(data)):
    
    data["nom"][k]=data["nom"][k].replace("'","")
    data["nom"][k]=data["nom"][k].replace('"',"")
    data["nom"][k]=data["nom"][k].replace("[","")
    data["nom"][k]=data["nom"][k].replace("]","")
data
# Out:
# /var/folders/5g/3_n1b4wj6rd2cr07gfh2bv6w0000gn/T/ipykernel_25466/2331774128.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["nom"][k]=data["nom"][k].replace("'","")
# /var/folders/5g/3_n1b4wj6rd2cr07gfh2bv6w0000gn/T/ipykernel_25466/2331774128.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["nom"][k]=data["nom"][k].replace('"',"")
# /var/folders/5g/3_n1b4wj6rd2cr07gfh2bv6w0000gn/T/ipykernel_25466/2331774128.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
for k in range (len(data)):
    
    data["image"][k]=data["image"][k].replace("'","")
    data["image"][k]=data["image"][k].replace('"',"")
    data["image"][k]=data["image"][k].replace("[","")
    data["image"][k]=data["image"][k].replace("]","")
data
# Out:
# /var/folders/5g/3_n1b4wj6rd2cr07gfh2bv6w0000gn/T/ipykernel_25466/1212703215.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["image"][k]=data["image"][k].replace("'","")
# /var/folders/5g/3_n1b4wj6rd2cr07gfh2bv6w0000gn/T/ipykernel_25466/1212703215.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["image"][k]=data["image"][k].replace('"',"")
# /var/folders/5g/3_n1b4wj6rd2cr07gfh2bv6w0000gn/T/ipykernel_25466/1212703215.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
for k in range (len(data)):
    
    data["score"][k]=data["score"][k].replace("'","")
    data["score"][k]=data["score"][k].replace('"',"")
    data["score"][k]=data["score"][k].replace("[","")
    data["score"][k]=data["score"][k].replace("]","")
data
# Out:
# /var/folders/5g/3_n1b4wj6rd2cr07gfh2bv6w0000gn/T/ipykernel_25466/1143980871.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["score"][k]=data["score"][k].replace("'","")
# /var/folders/5g/3_n1b4wj6rd2cr07gfh2bv6w0000gn/T/ipykernel_25466/1143980871.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["score"][k]=data["score"][k].replace('"',"")
# /var/folders/5g/3_n1b4wj6rd2cr07gfh2bv6w0000gn/T/ipykernel_25466/1143980871.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
for k in range (len(data)):
    if(len(data["score"][k])>=3):
        data["score"][k]=data["score"][k][0:3]
data
# Out:
# /var/folders/5g/3_n1b4wj6rd2cr07gfh2bv6w0000gn/T/ipykernel_25466/3093303085.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["score"][k]=data["score"][k][0:3]
#       annee                                               nom  \
# 0      2022                                         Mercredi
# 1      2022                                             1899
# 2      2010                                 The Walking Dead
# 3      2018                                         Manifest
# 4      2022   Le Cabinet de curiosités de Guillermo del Toro
# ...     ...                                               ...
# 8992   2015                                  Owarimonogatari
# 8993   2008                                             Flow
# 8994   2021                             Hetalia: World Stars
# ...

# %%
data=data[data.score!='nan']
data
# Out:
#       annee                                               nom  \
# 0      2022                                         Mercredi
# 1      2022                                             1899
# 2      2010                                 The Walking Dead
# 3      2018                                         Manifest
# 4      2022   Le Cabinet de curiosités de Guillermo del Toro
# ...     ...                                               ...
# 8990   2014                                   Hanamonogatari
# 8992   2015                                  Owarimonogatari
# 8993   2008                                             Flow
# 8994   2021                             Hetalia: World Stars
# 8995   2017                    Fate/Stay Night: Heavens Feel
#
#                                                 acteurs  \
# 0     [JennaOrtega, GwendolineChristie, PercyHynesWh...
# 1     [EmilyBeecham, AndreasPietschmann, AneurinBarn...
# 2     [NormanReedus, MelissaMcBride, LaurenCohan, Ch...
# ...

# %%
data = data.reset_index()
data
# Out:
#       index  annee                                               nom  \
# 0         0   2022                                         Mercredi
# 1         1   2022                                             1899
# 2         2   2010                                 The Walking Dead
# 3         3   2018                                         Manifest
# 4         4   2022   Le Cabinet de curiosités de Guillermo del Toro
# ...     ...    ...                                               ...
# 8280   8990   2014                                   Hanamonogatari
# 8281   8992   2015                                  Owarimonogatari
# 8282   8993   2008                                             Flow
# 8283   8994   2021                             Hetalia: World Stars
# 8284   8995   2017                    Fate/Stay Night: Heavens Feel
#
#                                                 acteurs  \
# 0     [JennaOrtega, GwendolineChristie, PercyHynesWh...
# ...

# %%
data['score'] = data['score'].astype(float)

# %%
df = data.sort_values(by='score',ascending=False)
df.head(30)
# Out:
#       index  annee                                      nom  \
# 3258   3418   2022                                पावनखिंड
# 5564   6128   2018                                   Bluey
# 3868   4064   2018                                   Bluey
# 22       24   2008                            Breaking Bad
# 5383   5943   2001                           Frères darmes
# 5367   5927   2019                               Chernobyl
# 7241   7862   2019                               Chernobyl
# 7245   7866   2001                           Frères darmes
# 411     426   2019                           Notre planète
# 125     131   2005      Avatar : Le dernier maître de lair
# 5355   5915   2002                              Sur écoute
# 7237   7858   2002                              Sur écoute
# 3863   4059   2021   11 septembre : un jour dans lhistoire
# 3679   3868   2021                                Jai Bhim
# 7859   8499   2005      Avatar : Le dernier maître de lair
# ...

# %%
df_e = data.explode("genres")
df_e
# Out:
#       index  annee                              nom  \
# 0         0   2022                        Mercredi
# 0         0   2022                        Mercredi
# 0         0   2022                        Mercredi
# 0         0   2022                        Mercredi
# 0         0   2022                        Mercredi
# ...     ...    ...                              ...
# 8282   8993   2008                            Flow
# 8283   8994   2021            Hetalia: World Stars
# 8283   8994   2021            Hetalia: World Stars
# 8284   8995   2017   Fate/Stay Night: Heavens Feel
# 8284   8995   2017   Fate/Stay Night: Heavens Feel
#
#                                                 acteurs           genres  \
# 0     [JennaOrtega, GwendolineChristie, PercyHynesWh...  Science-Fiction
# 0     [JennaOrtega, GwendolineChristie, PercyHynesWh...          Comédie
# 0     [JennaOrtega, GwendolineChristie, PercyHynesWh...   Crime&Thriller
# ...

# %%
df_e=df_e.reset_index(drop=True)
df_e
# Out:
#        index  annee                              nom  \
# 0          0   2022                        Mercredi
# 1          0   2022                        Mercredi
# 2          0   2022                        Mercredi
# 3          0   2022                        Mercredi
# 4          0   2022                        Mercredi
# ...      ...    ...                              ...
# 33017   8993   2008                            Flow
# 33018   8994   2021            Hetalia: World Stars
# 33019   8994   2021            Hetalia: World Stars
# 33020   8995   2017   Fate/Stay Night: Heavens Feel
# 33021   8995   2017   Fate/Stay Night: Heavens Feel
#
#                                                  acteurs           genres  \
# 0      [JennaOrtega, GwendolineChristie, PercyHynesWh...  Science-Fiction
# 1      [JennaOrtega, GwendolineChristie, PercyHynesWh...          Comédie
# 2      [JennaOrtega, GwendolineChristie, PercyHynesWh...   Crime&Thriller
# ...

# %%
genres_c=df_e['genres'].value_counts().to_frame()
genres_c.head(25)
# Out:
#                          genres
# Drame                      4774
# Comédie                    3123
# Mystère&Thriller           2462
# Action&Aventure            2409
# MadeinEurope               1681
# Crime&Thriller             1606
# Science-Fiction            1550
# Fantastique                1498
# ComédieRomantique          1460
# Pourenfants                1305
# Animation                  1285
# Horreur                     884
# Documentaire                723
# Histoire                    503
# Musique&ComédieMusicale     334
# Filmdeguerre                328
# Sport&Fitness               308
# RealityTV                   156
# Western                     137
# RidleyScott                  22
# MartinScorsese               20
# StevenSpielberg              20
# RobertZemeckis               18
# MichaelBay                   18
# MichaelHaneke                16

# %%
df_e["genres"]=df_e["genres"].replace(["ComédieRomantique"],"Comédie Romantique")
df_e
# Out:
#        index  annee                              nom  \
# 0          0   2022                        Mercredi
# 1          0   2022                        Mercredi
# 2          0   2022                        Mercredi
# 3          0   2022                        Mercredi
# 4          0   2022                        Mercredi
# ...      ...    ...                              ...
# 33017   8993   2008                            Flow
# 33018   8994   2021            Hetalia: World Stars
# 33019   8994   2021            Hetalia: World Stars
# 33020   8995   2017   Fate/Stay Night: Heavens Feel
# 33021   8995   2017   Fate/Stay Night: Heavens Feel
#
#                                                  acteurs           genres  \
# 0      [JennaOrtega, GwendolineChristie, PercyHynesWh...  Science-Fiction
# 1      [JennaOrtega, GwendolineChristie, PercyHynesWh...          Comédie
# 2      [JennaOrtega, GwendolineChristie, PercyHynesWh...   Crime&Thriller
# ...

# %%
df_e[df_e["genres"]=="Comédie Romantique"]
# Out:
#        index  annee                                                nom  \
# 102       30   1994                                           Friends
# 118       33   2015   Miraculous, les aventures de Ladybug et Chat ...
# 129       36   2013                                           Vikings
# 153       46   2021                                      Young Royals
# 191       57   2007                               The Big Bang Theory
# ...      ...    ...                                                ...
# 32807   8914   2017                                           BLEND-S
# 32822   8918   2020                                              Arte
# 32825   8919   2020                               Adachi to Shimamura
# 32942   8962   2019                                   Shoumetsu Toshi
# 32948   8966   2020                                          Nekopara
#
#                                                  acteurs              genres  \
# ...

# %%
df_e["genres"]=df_e["genres"].replace(["Filmdeguerre"],"Guerre")
df_e[df_e["genres"]=="Guerre"]
# Out:
#        index  annee                            nom  \
# 127       36   2013                       Vikings
# 161       48   2015    Gate - Au-delà de la porte
# 299       87   2015              The Last Kingdom
# 426      123   2018                     Bodyguard
# 433      126   2019                  Vinland Saga
# ...      ...    ...                            ...
# 31597   8606   2013          Code Lyoko Évolution
# 32406   8800   1995       Mobile Suit Gundam Wing
# 32671   8871   2018       Record of Grancrest War
# 32677   8873   2022   Le Requiem du Roi des Roses
# 32774   8904   2022              Heike Monogatari
#
#                                                  acteurs  genres  \
# 127    [AlexHøghAndersen, JordanPatrickSmith, MarcoIl...  Guerre
# 161                           [JunichiSuwabe, NaoToyama]  Guerre
# 299    [AlexanderDreymon, EmilyCox, ElizaButterworth,...  Guerre
# 426    [RichardMadden, KeeleyHawes, SophieRundle, Gin...  Guerre
# ...

# %%
df_e["type de contenu"].value_counts()
# Out:
# Film                17569
# Série                5647
# Dessin animé         3845
# Animation            3021
# Série en famille     2940
# Name: type de contenu, dtype: int64

# %%
df_n = df_e[df_e["platforme"] == "netflix"]
df_n
# Out:
#       index  annee                                   nom  \
# 0         0   2022                             Mercredi
# 1         0   2022                             Mercredi
# 2         0   2022                             Mercredi
# 3         0   2022                             Mercredi
# 4         0   2022                             Mercredi
# ...     ...    ...                                   ...
# 7360   1968   2022                       Balle perdue 2
# 7361   1969   2001   Harry Potter à lécole des sorciers
# 7362   1969   2001   Harry Potter à lécole des sorciers
# 7363   1969   2001   Harry Potter à lécole des sorciers
# 7364   1969   2001   Harry Potter à lécole des sorciers
#
#                                                 acteurs           genres  \
# 0     [JennaOrtega, GwendolineChristie, PercyHynesWh...  Science-Fiction
# 1     [JennaOrtega, GwendolineChristie, PercyHynesWh...          Comédie
# ...

# %%
df_adn = df_e[df_e["platforme"] == "adn"]
df_adn
# Out:
#        index  annee                    nom  \
# 31009   8487   2013   LAttaque des Titans
# 31010   8487   2013   LAttaque des Titans
# 31011   8487   2013   LAttaque des Titans
# 31012   8487   2013   LAttaque des Titans
# 31013   8487   2013   LAttaque des Titans
# ...      ...    ...                    ...
# 32236   8768   1981   Kié la petite peste
# 32237   8768   1981   Kié la petite peste
# 32238   8768   1981   Kié la petite peste
# 32239   8768   1981   Kié la petite peste
# 32240   8768   1981   Kié la petite peste
#
#                                                  acteurs           genres  \
# 31009  [YukiKaji, YuiIshikawa, MarinaInoue, KishoTani...  Action&Aventure
# 31010  [YukiKaji, YuiIshikawa, MarinaInoue, KishoTani...  Science-Fiction
# 31011  [YukiKaji, YuiIshikawa, MarinaInoue, KishoTani...        Animation
# 31012  [YukiKaji, YuiIshikawa, MarinaInoue, KishoTani...            Drame
# 31013  [YukiKaji, YuiIshikawa, MarinaInoue, KishoTani...      Fantastique
# ...

# %%
df_am = df_e[df_e["platforme"] == "amazon"]
df_am
# Out:
#        index  annee                                          nom  \
# 7365    1970   2022         Périphériques, Les Mondes de Flynne
# 7366    1970   2022         Périphériques, Les Mondes de Flynne
# 7367    1970   2022         Périphériques, Les Mondes de Flynne
# 7368    1971   2017   The Handmaids Tale : La servante écarlate
# 7369    1971   2017   The Handmaids Tale : La servante écarlate
# ...      ...    ...                                          ...
# 14753   3928   1967                           Opération Re Mida
# 14754   3929   1997                                 Assassin(s)
# 14755   3929   1997                                 Assassin(s)
# 14756   3929   1997                                 Assassin(s)
# 14757   3929   1997                                 Assassin(s)
#
#                                                  acteurs            genres  \
# 7365   [ChloëGraceMoretz, GaryCarr, JackReynor, JJFei...   Science-Fiction
# ...

# %%
df_c = df_e[df_e["platforme"] == "canal"]
df_c
# Out:
#        index  annee                    nom  \
# 21352   5890   2022   House of the Dragon
# 21353   5890   2022   House of the Dragon
# 21354   5890   2022   House of the Dragon
# 21355   5890   2022   House of the Dragon
# 21356   5890   2022   House of the Dragon
# ...      ...    ...                    ...
# 28745   7849   2013        Closed Circuit
# 28746   7849   2013        Closed Circuit
# 28747   7849   2013        Closed Circuit
# 28748   7849   2013        Closed Circuit
# 28749   7849   2013        Closed Circuit
#
#                                                  acteurs              genres  \
# 21352  [PaddyConsidine, MattSmith, EmmaD\\Arcy, Olivi...     Action&Aventure
# 21353  [PaddyConsidine, MattSmith, EmmaD\\Arcy, Olivi...     Science-Fiction
# 21354  [PaddyConsidine, MattSmith, EmmaD\\Arcy, Olivi...               Drame
# 21355  [PaddyConsidine, MattSmith, EmmaD\\Arcy, Olivi...         Fantastique
# ...

# %%
df_d = df_e[df_e["platforme"] == "disney"]
df_d
# Out:
#        index  annee                       nom  \
# 14758   3930   2022        Star Wars : Andor
# 14759   3930   2022        Star Wars : Andor
# 14760   3930   2022        Star Wars : Andor
# 14761   3930   2022        Star Wars : Andor
# 14762   3930   2022        Star Wars : Andor
# ...      ...    ...                       ...
# 21347   5886   1977   A Tale of Two Critters
# 21348   5886   1977   A Tale of Two Critters
# 21349   5887   1965    Calloway, le trappeur
# 21350   5887   1965    Calloway, le trappeur
# 21351   5887   1965    Calloway, le trappeur
#
#                                                  acteurs            genres  \
# 14758  [DiegoLuna, StellanSkarsgård, KyleSoller, Adri...   Science-Fiction
# 14759  [DiegoLuna, StellanSkarsgård, KyleSoller, Adri...   Action&Aventure
# 14760  [DiegoLuna, StellanSkarsgård, KyleSoller, Adri...            Guerre
# 14761  [DiegoLuna, StellanSkarsgård, KyleSoller, Adri...             Drame
# ...

# %%
df_ocs = df_e[df_e["platforme"] == "ocs"]
df_ocs
# Out:
#        index  annee                     nom  \
# 28750   7850   2022    House of the Dragon
# 28751   7850   2022    House of the Dragon
# 28752   7850   2022    House of the Dragon
# 28753   7850   2022    House of the Dragon
# 28754   7850   2022    House of the Dragon
# ...      ...    ...                     ...
# 31004   8481   2021            Vulnérables
# 31005   8481   2021            Vulnérables
# 31006   8482   1993   Ordeal in the Arctic
# 31007   8486   1998         La Sauvageonne
# 31008   8486   1998         La Sauvageonne
#
#                                                  acteurs              genres  \
# 28750  [PaddyConsidine, MattSmith, EmmaD\\Arcy, Olivi...     Science-Fiction
# 28751  [PaddyConsidine, MattSmith, EmmaD\\Arcy, Olivi...               Drame
# 28752  [PaddyConsidine, MattSmith, EmmaD\\Arcy, Olivi...     Action&Aventure
# 28753  [PaddyConsidine, MattSmith, EmmaD\\Arcy, Olivi...         Fantastique
# ...

# %%
df_w = df_e[df_e["platforme"] == "wakanim"]
df_w
# Out:
#        index  annee                              nom  \
# 32241   8769   2013             LAttaque des Titans
# 32242   8769   2013             LAttaque des Titans
# 32243   8769   2013             LAttaque des Titans
# 32244   8769   2013             LAttaque des Titans
# 32245   8769   2013             LAttaque des Titans
# ...      ...    ...                              ...
# 33017   8993   2008                            Flow
# 33018   8994   2021            Hetalia: World Stars
# 33019   8994   2021            Hetalia: World Stars
# 33020   8995   2017   Fate/Stay Night: Heavens Feel
# 33021   8995   2017   Fate/Stay Night: Heavens Feel
#
#                                                  acteurs           genres  \
# 32241  [YukiKaji, YuiIshikawa, MarinaInoue, KishoTani...  Action&Aventure
# 32242  [YukiKaji, YuiIshikawa, MarinaInoue, KishoTani...  Science-Fiction
# 32243  [YukiKaji, YuiIshikawa, MarinaInoue, KishoTani...        Animation
# ...

# %%
df_e[df_e["type de contenu"]=='Série en famille'].groupby("platforme").count()
# Out:
#            index  annee   nom  acteurs  genres  image  score  type de contenu
# platforme
# amazon       367    367   367      367     367    367    367              367
# canal        297    297   297      297     297    297    297              297
# disney      1770   1770  1770     1770    1770   1770   1770             1770
# netflix      433    433   433      433     433    433    433              433
# ocs           73     73    73       73      73     73     73               73

# %%
adn=['Animation']
amazon=['Action&Aventure','Mystère&Thriller','Horreur','Film']
canal=['Guerre','Histoire','Comédie Romantique','Drame','MadeinEurope','Crime&Thriller','Western','RealityTV','Série']
disney=['Sport&Fitness','Comédie','Fantastique','Musique&ComédieMusicale','RealityTV','Documentaire','Dessin animé','Série en famille']
netflix=['Science-Fiction']
ocs=[]
wakanim=['Animation']

# %%
conda install pillow
# Out:
# Retrieving notices: ...working... done
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from tkinter import *
from tkinter import ttk
import os
from datetime import date
from random import sample


class MonApp:
    def __init__(self,menu):
        self.menu=menu
        #self.lbl1=Label(menu,text="Apprenons à nous connaître!",font=("Arial",20),bg='#A50021',fg='white')
        #self.lbl1.place(x=530,y=450)
        self.btn1=Button(menu,text="Je suis prêt(e)",bg='white',font=("Arial",15),width = 15,command=self.new_window)
        self.btn1.place(x=560,y=450)
        
        self.ad = 0
        self.a = 0
        self.can = 0
        self.dis = 0
        self.net = 0
        self.o = 0
        self.wak = 0
        
        
        
    

    
    def new_window(self):
        
        
        self.newWindow=Toplevel(self.menu)
        self.newWindow.title("infos")
        self.newWindow.geometry("1270x640+0+0")
        self.newWindow.configure(bg='#A50021')
        self.lbl2=Label(self.newWindow,text="Vos infos personnelles",font=("Arial",30,'bold','underline'),bg ='#A50021',fg='white' )
        self.lbl2.place(x=450,y=30)
        
        self.lbl3=Label(self.newWindow,text="Name:",font=('Arial',18,'bold'),bg ='#A50021',fg='white')
        self.lbl3.place(x=550,y=190)
        self.e=Entry(self.newWindow)
        self.e.place(x=700,y=200)
        self.lbl4=Label(self.newWindow,text="Mail:",bg ='#A50021',fg='white',font=('Arial',18,'bold'))
        self.lbl4.place(x=550,y=290)
        self.e2=Entry(self.newWindow)
        self.e2.place(x=700,y=300)
        self.lbl5=Label(self.newWindow,text="Date Naissance:",bg ='#A50021',fg='white',font=('Arial',18,'bold'))
        self.lbl5.place(x=430,y=390)
        self.e3=Entry(self.newWindow)
        self.e3.place(x=700,y=400)
        self.lbl6=Label(self.newWindow,text="Pays de résidence:",bg ='#A50021',fg='white',font=('Arial',18,'bold'))
        self.lbl6.place(x=410,y=490)
        self.e4=Entry(self.newWindow)
        self.e4.place(x=700,y=500)
        self.btn4=Button(self.newWindow,text="Suivant",bg='white',font=("Arial",15),command=self.create)
        self.btn4.place(x=600,y=580)
        #self.btn5=Button(self.newWindow,text="delete cus",font=("Courier",15),command=self.delete)
        #self.btn5.place(x=180,y=20)
        #self.btn7=Button(self.newWindow,text="transactions",font=("Courier",15),command=self.trans)
        #self.btn7.place(x=340,y=20)
        #self.btn8=Button(self.newWindow,text="List cus",font=("Courier",15),command=self.list_cust)
        #self.btn8.place(x=540,y=20)
    
        
        
        
            
            
        
        
        

        
        
        
        
    
    def create(self):
        
        Nom = str(self.e.get()).upper()
        Mail=str(self.e2.get()).upper()
        Date = str(self.e3.get())
        Pays =  str(self.e4.get())
        with open("Client.txt",mode="a") as fichier:
            fichier.write("{}\t\t\t{}\t\t\t{}\t\t\t{} \n".format(Nom,Mail,Date,Pays))
        
        self.newWindow3=Toplevel(self.newWindow)
        self.newWindow3.title("Questions")
        self.newWindow3.geometry("1270x640+0+0")
        self.newWindow3.configure(bg='#A50021')
        
        
        self.lblTitle = Label(self.newWindow3,text="Dites-nous en plus sur vos goûts",font=("Arial",25,'bold','underline'),bg ='#A50021',fg='white')
        self.lblTitle.pack()
        
        self.lblQ1 = Label(self.newWindow3,text="Genres préférés?",font=("Arial",15,'bold'),bg ='#A50021',fg='white')
        self.lblQ1.place(x=40,y=70)
        
        self.var1 = IntVar()
        self.c1 = Checkbutton(self.newWindow3, text='Action&Aventure',variable=self.var1,onvalue=1, offvalue=0,font=("Courier",11,'bold'),bg ='#A50021')
        self.c1.place(x=40,y=100)
    
        self.var2 = IntVar()
        self.c2 = Checkbutton(self.newWindow3, text='Guerre',variable=self.var2,onvalue=1, offvalue=0,font=("Courier",11,'bold'),bg ='#A50021')
        self.c2.place(x=220,y=100)
        
        self.var3 = IntVar()
        self.c3 = Checkbutton(self.newWindow3, text='Histoire',variable=self.var3,onvalue=1, offvalue=0,font=("Courier",11,'bold'),bg ='#A50021')
        self.c3.place(x=400,y=100)
        
        self.var4 = IntVar()
        self.c4 = Checkbutton(self.newWindow3, text='Sport&Fitness',variable=self.var4,onvalue=1, offvalue=0,font=("Courier",11,'bold'),bg ='#A50021')
        self.c4.place(x=580,y=100)
        
        self.var5 = IntVar()
        self.c5 = Checkbutton(self.newWindow3, text='Comédie',variable=self.var5,onvalue=1, offvalue=0,font=("Courier",11,'bold'),bg ='#A50021')
        self.c5.place(x=760,y=100)
        
        self.var6 = IntVar()
        self.c6 = Checkbutton(self.newWindow3, text='Comédie Romantique',variable=self.var6,onvalue=1, offvalue=0,font=("Courier",11,'bold'),bg ='#A50021')
        self.c6.place(x=940,y=100)
        
        self.var7 = IntVar()
        self.c7 = Checkbutton(self.newWindow3, text='Drame',variable=self.var7,onvalue=1, offvalue=0,font=("Courier",11,'bold'),bg ='#A50021')
        self.c7.place(x=40,y=160)
        
        self.var8 = IntVar()
        self.c8 = Checkbutton(self.newWindow3, text='Fantastique',variable=self.var8,onvalue=1, offvalue=0,font=("Courier",11,'bold'),bg ='#A50021')
        self.c8.place(x=220,y=160)
        
        self.var9 = IntVar()
        self.c9 = Checkbutton(self.newWindow3, text='Mystère&Thriller',variable=self.var9,onvalue=1, offvalue=0,font=("Courier",11,'bold'),bg ='#A50021')
        self.c9.place(x=400,y=160)
        
        self.var10 = IntVar()
        self.c10 = Checkbutton(self.newWindow3, text='MadeinEurope',variable=self.var10,onvalue=1, offvalue=0,font=("Courier",11,'bold'),bg ='#A50021')
        self.c10.place(x=580,y=160)
        
        self.var11 = IntVar()
        self.c11 = Checkbutton(self.newWindow3, text='Science-Fiction',variable=self.var11,onvalue=1, offvalue=0,font=("Courier",11,'bold'),bg ='#A50021')
        self.c11.place(x=760,y=160)
        
        self.var12 = IntVar()
        self.c12 = Checkbutton(self.newWindow3, text='Musique&ComédieMusicale',variable=self.var12,onvalue=1, offvalue=0,font=("Courier",11,'bold'),bg ='#A50021')
        self.c12.place(x=940,y=160)
        
        self.var13 = IntVar()
        self.c13 = Checkbutton(self.newWindow3, text='Crime&Thriller',variable=self.var13,onvalue=1, offvalue=0,font=("Courier",11,'bold'),bg ='#A50021')
        self.c13.place(x=40,y=220)
        
        self.var15 = IntVar()
        self.c15 = Checkbutton(self.newWindow3, text='Horreur',variable=self.var15,onvalue=1, offvalue=0,font=("Courier",11,'bold'),bg ='#A50021')
        self.c15.place(x=220,y=220)
        
        self.var16 = IntVar()
        self.c16 = Checkbutton(self.newWindow3, text='Western',variable=self.var16,onvalue=1, offvalue=0,font=("Courier",11,'bold'),bg ='#A50021')
        self.c16.place(x=400,y=220)
        
        self.var17 = IntVar()
        self.c17 = Checkbutton(self.newWindow3, text='RealityTV',variable=self.var17,onvalue=1, offvalue=0,font=("Courier",11,'bold'),bg ='#A50021')
        self.c17.place(x=580,y=220)
        
        self.var18 = IntVar()
        self.c18 = Checkbutton(self.newWindow3, text='Documentaire',variable=self.var18,onvalue=1, offvalue=0,font=("Courier",11,'bold'),bg ='#A50021')
        self.c18.place(x=760,y=220)
        
        self.lblQ2 = Label(self.newWindow3,text="Type préférés?",font=("Arial",15,'bold'),bg ='#A50021',fg='white')
        self.lblQ2.place(x=40,y=300)
        
        self.var19 = IntVar()
        self.c19 = Checkbutton(self.newWindow3, text='Film',variable=self.var19,onvalue=1, offvalue=0,font=("Courier",14,'bold'),bg ='#A50021')
        self.c19.place(x=40,y=330)
        
        self.var20 = IntVar()
        self.c20 = Checkbutton(self.newWindow3, text='Série',variable=self.var20,onvalue=1, offvalue=0,font=("Courier",14,'bold'),bg ='#A50021')
        self.c20.place(x=240,y=330)
        
        self.var21 = IntVar()
        self.c21 = Checkbutton(self.newWindow3, text='Animation',variable=self.var21,onvalue=1, offvalue=0,font=("Courier",14,'bold'),bg ='#A50021')
        self.c21.place(x=440,y=330)
        
        self.var22 = IntVar()
        self.c22 = Checkbutton(self.newWindow3, text='Dessin animé',variable=self.var22,onvalue=1, offvalue=0,font=("Courier",14,'bold'),bg ='#A50021')
        self.c22.place(x=640,y=330)
        
        self.var23 = IntVar()
        self.c23 = Checkbutton(self.newWindow3, text='Série en famille',variable=self.var23,onvalue=1, offvalue=0,font=("Courier",14,'bold'),bg ='#A50021')
        self.c23.place(x=840,y=330)
        
        self.btnS = Button(self.newWindow3,text="Suivant",bg='white',font=("Arial",15),command=self.suivant)
        self.btnS.place(x=600,y=500)
        
        
    def suivant(self):
    
        self.lblQ1.place_forget()
        self.lblQ2.place_forget()
        self.c1.place_forget()
        self.c2.place_forget()
        self.c3.place_forget()
        self.c4.place_forget()
        self.c5.place_forget()
        self.c6.place_forget()
        self.c7.place_forget()
        self.c8.place_forget()
        self.c9.place_forget()
        self.c10.place_forget()
        self.c11.place_forget()
        self.c12.place_forget()
        self.c13.place_forget()
        self.c15.place_forget()
        self.c16.place_forget()
        self.c17.place_forget()
        self.c18.place_forget()
        self.c19.place_forget()
        self.c20.place_forget()
        self.c21.place_forget()
        self.c22.place_forget()
        self.c23.place_forget()
        self.btnS.place_forget()
        
        self.lblQ3 = Label(self.newWindow3,text="Parmi la sélection suivante, que préférez-vous regarder?",font=("Arial",15,'bold'),bg ='#A50021',fg='white')
        self.lblQ3.place(x=40,y=70)
        self.lblQ3_1 = Label(self.newWindow3,text="1)",font=("Arial",15,'bold'),bg ='#A50021',fg='white')
        self.lblQ3_1.place(x=40,y=140)
        self.lblQ3_2 = Label(self.newWindow3,text="2)",font=("Arial",15,'bold'),bg ='#A50021',fg='white')
        self.lblQ3_2.place(x=40,y=240)
        self.lblQ3_3 = Label(self.newWindow3,text="3)",font=("Arial",15,'bold'),bg ='#A50021',fg='white')
        self.lblQ3_3.place(x=40,y=340)
        self.btnS2 = self.btnS = Button(self.newWindow3,text="Suivant",bg='white',font=("Arial",15),command=self.suivant2)
        self.btnS2.place(x=600,y=500)
        
        self.results=[]
        self.results_t = []
        if(self.var1.get()==1):
            self.results.append(self.c1.cget("text"))
        
        if(self.var2.get()==1):
            self.results.append(self.c2.cget("text"))
            
        if(self.var3.get()==1):
            self.results.append(self.c3.cget("text"))
            
        if(self.var4.get()==1):
            self.results.append(self.c4.cget("text"))
            
        if(self.var5.get()==1):
            self.results.append(self.c5.cget("text"))
            
        if(self.var6.get()==1):
            self.results.append(self.c6.cget("text"))
            
        if(self.var7.get()==1):
            self.results.append(self.c7.cget("text"))
            
        if(self.var8.get()==1):
            self.results.append(self.c8.cget("text"))
            
        if(self.var9.get()==1):
            self.results.append(self.c9.cget("text"))
            
        if(self.var10.get()==1):
            self.results.append(self.c10.cget("text"))
            
        if(self.var11.get()==1):
            self.results.append(self.c11.cget("text"))
            
        if(self.var12.get()==1):
            self.results.append(self.c12.cget("text"))
        
        if(self.var13.get()==1):
            self.results.append(self.c13.cget("text"))
            
        if(self.var15.get()==1):
            self.results.append(self.c15.cget("text"))
            
        if(self.var16.get()==1):
            self.results.append(self.c16.cget("text"))
            
        if(self.var17.get()==1):
            self.results.append(self.c17.cget("text"))
            
        if(self.var18.get()==1):
            self.results.append(self.c18.cget("text"))
            
        if(self.var19.get()==1):
            self.results_t.append(self.c19.cget("text"))
            
        if(self.var20.get()==1):
            self.results_t.append(self.c20.cget("text"))
            
        if(self.var21.get()==1):
            self.results_t.append(self.c21.cget("text"))
            
        if(self.var22.get()==1):
            self.results_t.append(self.c22.cget("text"))
            
        if(self.var23.get()==1):
            self.results_t.append(self.c23.cget("text"))
            
        
        for item in self.results:
            if (item in adn):
                self.ad+=2
            if (item in amazon):
                self.a+=2
            if(item in canal):
                self.can+=2
            if(item in ocs):
                self.o+=2
            if(item in disney):
                self.dis+=2
            if(item in wakanim):
                self.wak+=2
            if(item in netflix):
                self.net+=2
        
        for item in self.results_t:
            if (item in adn):
                self.ad+=2
            if (item in amazon):
                self.a+=2
            if(item in canal):
                self.can+=2
            if(item in ocs):
                self.o+=2
            if(item in disney):
                self.dis+=2
            if(item in wakanim):
                self.wak+=2
            if(item in netflix):
                self.net+=2
        
               
        if('Animation' in self.results_t):
            if(len(self.results_t)==1):
                self.var = StringVar()
                self.R1 = Radiobutton(self.newWindow3, text="{}".format(df_w[(df_w["type de contenu"]=='Animation')&(df_w["score"]>=8.5)].nom.sample(1).values[0]), variable=self.var, value="{}".format(df_n[(df_n["type de contenu"]==self.rdm_t[0])&(df_n["score"]>=8)&(df_n["genres"]==self.rdm_g[0])].nom.sample(1).values[0]),font=("Courier",11,'bold'),bg ='#A50021')
                self.R1.place( x=150,y=160 )

                self.R2 = Radiobutton(self.newWindow3, text="{}".format(df_adn[(df_adn["type de contenu"]=='Animation')&(df_adn["score"]>=8.5)].nom.sample(1).values[0]), variable=self.var, value=2,font=("Courier",11,'bold'),bg ='#A50021')
                self.R2.place( x=400,y=160 )
        else:
            self.rdm_g = sample(self.results,1)
            self.rdm_t = sample(self.results_t,1)
            self.var = StringVar()
           
            self.name1="{}".format(df_n[(df_n["type de contenu"]==self.rdm_t[0])&(df_n["score"]>=8)&(df_n["genres"]==self.rdm_g[0])].nom.sample(1).values[0])
            
            self.R1 = Radiobutton(self.newWindow3, text=self.name1, variable=self.var, value=self.name1,font=("Courier",11,'bold'),bg ='#A50021')
            self.R1.place( x=150,y=160 )

            self.name2="{}".format(df_am[(df_am["type de contenu"]==self.rdm_t[0])&(df_am["score"]>=8)&(df_am["genres"]==self.rdm_g[0])].nom.sample(1).values[0])
            
            self.R2 = Radiobutton(self.newWindow3, text=self.name2, variable=self.var, value=self.name2,font=("Courier",11,'bold'),bg ='#A50021')
            self.R2.place( x=650,y=160 )
            
            self.name3 = "{}".format(df_d[(df_d["type de contenu"]==self.rdm_t[0])&(df_d["score"]>=8)&(df_d["genres"]==self.rdm_g[0])].nom.sample(1).values[0])
            
            self.R3 = Radiobutton(self.newWindow3, text=self.name3, variable=self.var, value=self.name3,font=("Courier",11,'bold'),bg ='#A50021')
            self.R3.place( x=650,y=200 )
            
            self.name4 = "{}".format(df_c[(df_c["type de contenu"]==self.rdm_t[0])&(df_c["score"]>=8)&(df_c["genres"]==self.rdm_g[0])].nom.sample(1).values[0])
            
            self.R4 = Radiobutton(self.newWindow3, text=self.name4, variable=self.var, value=self.name4,font=("Courier",11,'bold'),bg ='#A50021')
            self.R4.place( x=150,y=200 )
            
            #2
            self.rdm_g2 = sample(self.results,1)
            self.rdm_t2 = sample(self.results_t,1)
            self.var2 = StringVar()
            
            self.name5 = "{}".format(df_n[(df_n["type de contenu"]==self.rdm_t2[0])&(df_n["score"]>=8)&(df_n["genres"]==self.rdm_g2[0])].nom.sample(1).values[0])
            
            self.R5 = Radiobutton(self.newWindow3, text= self.name5, variable=self.var2, value=self.name5,font=("Courier",11,'bold'),bg ='#A50021')
            self.R5.place( x=150,y=260 )

            self.name6 = "{}".format(df_am[(df_am["type de contenu"]==self.rdm_t2[0])&(df_am["score"]>=8)&(df_am["genres"]==self.rdm_g2[0])].nom.sample(1).values[0])
            
            self.R6 = Radiobutton(self.newWindow3, text=self.name6, variable=self.var2, value=self.name6,font=("Courier",11,'bold'),bg ='#A50021')
            self.R6.place( x=650,y=260 )
            
            self.name7 = "{}".format(df_d[(df_d["type de contenu"]==self.rdm_t2[0])&(df_d["score"]>=8)&(df_d["genres"]==self.rdm_g2[0])].nom.sample(1).values[0])
            
            self.R7 = Radiobutton(self.newWindow3, text= self.name7, variable=self.var2, value= self.name7,font=("Courier",11,'bold'),bg ='#A50021')
            self.R7.place( x=650,y=300 )
            
            self.name8 = "{}".format(df_c[(df_c["type de contenu"]==self.rdm_t2[0])&(df_c["score"]>=8)&(df_c["genres"]==self.rdm_g2[0])].nom.sample(1).values[0])
            
            self.R8 = Radiobutton(self.newWindow3, text= self.name8, variable=self.var2, value=self.name8,font=("Courier",11,'bold'),bg ='#A50021')
            self.R8.place( x=150,y=300 )
            
            #3
            self.rdm_g3 = sample(self.results,1)
            self.rdm_t3 = sample(self.results_t,1)
            self.var3 = StringVar()
            
            self.name9 = "{}".format(df_n[(df_n["type de contenu"]==self.rdm_t3[0])&(df_n["score"]>=8)&(df_n["genres"]==self.rdm_g3[0])].nom.sample(1).values[0])
            
            self.R9 = Radiobutton(self.newWindow3, text= self.name9, variable=self.var3, value=self.name9,font=("Courier",11,'bold'),bg ='#A50021')
            self.R9.place( x=150,y=360 )
            
            self.name10 = "{}".format(df_am[(df_am["type de contenu"]==self.rdm_t3[0])&(df_am["score"]>=8)&(df_am["genres"]==self.rdm_g3[0])].nom.sample(1).values[0])

            self.R10 = Radiobutton(self.newWindow3, text=self.name10, variable=self.var3, value=self.name10,font=("Courier",11,'bold'),bg ='#A50021')
            self.R10.place( x=650,y=360 )
            
            self.name11 = "{}".format(df_d[(df_d["type de contenu"]==self.rdm_t3[0])&(df_d["score"]>=8)&(df_d["genres"]==self.rdm_g3[0])].nom.sample(1).values[0])
            
            self.R11 = Radiobutton(self.newWindow3, text=self.name11, variable=self.var3, value=self.name11,font=("Courier",11,'bold'),bg ='#A50021')
            self.R11.place( x=650,y=400 )
            
            self.name12 = "{}".format(df_c[(df_c["type de contenu"]==self.rdm_t3[0])&(df_c["score"]>=8)&(df_c["genres"]==self.rdm_g3[0])].nom.sample(1).values[0])
            
            self.R12 = Radiobutton(self.newWindow3, text=self.name12, variable=self.var3, value=self.name12,font=("Courier",11,'bold'),bg ='#A50021')
            self.R12.place( x=150,y=400 )
            
            #print(self.rdm_g[0]) 
            #print(df_n[(df_n["type de contenu"]==self.rdm_t[0])&(df_n["score"]>=8.5)&(df_n["genres"]==self.rdm_g[0])].nom.sample(1).values[0])
    
 
    def suivant2(self):
        self.lblQ3_1.place_forget()
        self.lblQ3_2.place_forget()
        self.lblQ3_3.place_forget()
        self.R1.place_forget()
        self.R2.place_forget()
        self.R3.place_forget()
        self.R4.place_forget()
        self.R5.place_forget()
        self.R6.place_forget()
        self.R7.place_forget()
        self.R8.place_forget()
        self.R9.place_forget()
        self.R10.place_forget()
        self.R11.place_forget()
        self.R12.place_forget()
        self.btnS2.place_forget()
        
        if(self.var.get()==self.name1):
            self.net+=2
        if(self.var.get()==self.name2):
            self.a+=2
        if(self.var.get()==self.name3):
            self.dis+=2
        if(self.var.get()==self.name4):
            self.can+=2
        if(self.var2.get()==self.name5):
            self.net+=2
        if(self.var2.get()==self.name6):
            self.a+=2
        if(self.var2.get()==self.name7):
            self.dis+=2
        if(self.var2.get()==self.name8):
            self.can+=2
        if(self.var3.get()==self.name9):
            self.net+=2
        if(self.var3.get()==self.name10):
            self.a+=2
        if(self.var3.get()==self.name11):
            self.dis+=2
        if(self.var3.get()==self.name12):
            self.can+=2
            
        self.lblQ3_4 = Label(self.newWindow3,text="4)",font=("Arial",15,'bold'),bg ='#A50021',fg='white')
        self.lblQ3_4.place(x=40,y=140)
        self.lblQ3_5 = Label(self.newWindow3,text="5)",font=("Arial",15,'bold'),bg ='#A50021',fg='white')
        self.lblQ3_5.place(x=40,y=240)
        self.lblQ3_6 = Label(self.newWindow3,text="6)",font=("Arial",15,'bold'),bg ='#A50021',fg='white')
        self.lblQ3_6.place(x=40,y=340)
        self.btnR = self.btnS = Button(self.newWindow3,text="Résultat",bg='white',font=("Arial",15),command=self.calcul)
        self.btnR.place(x=600,y=500)
        
        #4
        self.rdm_g4 = sample(self.results,1)
        self.rdm_t4 = sample(self.results_t,1)
        self.var4 = StringVar()
       
        self.name13="{}".format(df_n[(df_n["type de contenu"]==self.rdm_t4[0])&(df_n["score"]>=8)&(df_n["genres"]==self.rdm_g4[0])].nom.sample(1).values[0])
            
        self.R13 = Radiobutton(self.newWindow3, text=self.name13, variable=self.var4, value=self.name13,font=("Courier",11,'bold'),bg ='#A50021')
        self.R13.place( x=150,y=160 )

        self.name14="{}".format(df_am[(df_am["type de contenu"]==self.rdm_t4[0])&(df_am["score"]>=8)&(df_am["genres"]==self.rdm_g4[0])].nom.sample(1).values[0])

        self.R14 = Radiobutton(self.newWindow3, text=self.name14, variable=self.var4, value=self.name14,font=("Courier",11,'bold'),bg ='#A50021')
        self.R14.place( x=650,y=160 )
            
        self.name15 = "{}".format(df_d[(df_d["type de contenu"]==self.rdm_t4[0])&(df_d["score"]>=8)&(df_d["genres"]==self.rdm_g4[0])].nom.sample(1).values[0])
            
        self.R15 = Radiobutton(self.newWindow3, text=self.name15, variable=self.var4, value=self.name15,font=("Courier",11,'bold'),bg ='#A50021')
        self.R15.place( x=650,y=200 )
            
        self.name16 = "{}".format(df_c[(df_c["type de contenu"]==self.rdm_t4[0])&(df_c["score"]>=8)&(df_c["genres"]==self.rdm_g4[0])].nom.sample(1).values[0])
            
        self.R16 = Radiobutton(self.newWindow3, text=self.name16, variable=self.var4, value=self.name16,font=("Courier",11,'bold'),bg ='#A50021')
        self.R16.place( x=150,y=200 )
        
        #5
        self.rdm_g5 = sample(self.results,1)
        self.rdm_t5 = sample(self.results_t,1)
        self.var5 = StringVar()
       
        self.name17="{}".format(df_n[(df_n["type de contenu"]==self.rdm_t5[0])&(df_n["score"]>=8)&(df_n["genres"]==self.rdm_g5[0])].nom.sample(1).values[0])
            
        self.R17 = Radiobutton(self.newWindow3, text=self.name17, variable=self.var5, value=self.name17,font=("Courier",11,'bold'),bg ='#A50021')
        self.R17.place( x=150,y=260 )

        self.name18="{}".format(df_am[(df_am["type de contenu"]==self.rdm_t5[0])&(df_am["score"]>=8)&(df_am["genres"]==self.rdm_g5[0])].nom.sample(1).values[0])

        self.R18 = Radiobutton(self.newWindow3, text=self.name18, variable=self.var5, value=self.name18,font=("Courier",11,'bold'),bg ='#A50021')
        self.R18.place( x=650,y=260 )
            
        self.name19 = "{}".format(df_d[(df_d["type de contenu"]==self.rdm_t5[0])&(df_d["score"]>=8)&(df_d["genres"]==self.rdm_g5[0])].nom.sample(1).values[0])
            
        self.R19 = Radiobutton(self.newWindow3, text=self.name19, variable=self.var5, value=self.name19,font=("Courier",11,'bold'),bg ='#A50021')
        self.R19.place( x=650,y=300 )
            
        self.name20 = "{}".format(df_c[(df_c["type de contenu"]==self.rdm_t5[0])&(df_c["score"]>=8)&(df_c["genres"]==self.rdm_g5[0])].nom.sample(1).values[0])
            
        self.R20 = Radiobutton(self.newWindow3, text=self.name20, variable=self.var5, value=self.name20,font=("Courier",11,'bold'),bg ='#A50021')
        self.R20.place( x=150,y=300 )
        
        #6
        self.rdm_g6 = sample(self.results,1)
        self.rdm_t6 = sample(self.results_t,1)
        self.var6 = StringVar()
       
        self.name21="{}".format(df_n[(df_n["type de contenu"]==self.rdm_t6[0])&(df_n["score"]>=8)&(df_n["genres"]==self.rdm_g6[0])].nom.sample(1).values[0])
            
        self.R21 = Radiobutton(self.newWindow3, text=self.name21, variable=self.var6, value=self.name21,font=("Courier",11,'bold'),bg ='#A50021')
        self.R21.place( x=150,y=360 )

        self.name22="{}".format(df_am[(df_am["type de contenu"]==self.rdm_t6[0])&(df_am["score"]>=8)&(df_am["genres"]==self.rdm_g6[0])].nom.sample(1).values[0])

        self.R22 = Radiobutton(self.newWindow3, text=self.name22, variable=self.var6, value=self.name22,font=("Courier",11,'bold'),bg ='#A50021')
        self.R22.place( x=650,y=360 )
            
        self.name23 = "{}".format(df_d[(df_d["type de contenu"]==self.rdm_t6[0])&(df_d["score"]>=8)&(df_d["genres"]==self.rdm_g6[0])].nom.sample(1).values[0])
            
        self.R23 = Radiobutton(self.newWindow3, text=self.name23, variable=self.var6, value=self.name23,font=("Courier",11,'bold'),bg ='#A50021')
        self.R23.place( x=650,y=400 )
            
        self.name24 = "{}".format(df_c[(df_c["type de contenu"]==self.rdm_t6[0])&(df_c["score"]>=8)&(df_c["genres"]==self.rdm_g6[0])].nom.sample(1).values[0])
            
        self.R24 = Radiobutton(self.newWindow3, text=self.name24, variable=self.var6, value=self.name24,font=("Courier",11,'bold'),bg ='#A50021')
        self.R24.place( x=150,y=400 )
        
        
        
    def calcul(self):
        
        self.lblQ3_4.place_forget()
        self.lblQ3_5.place_forget()
        self.lblQ3_6.place_forget()
        self.R13.place_forget()
        self.R14.place_forget()
        self.R15.place_forget()
        self.R16.place_forget()
        self.R17.place_forget()
        self.R18.place_forget()
        self.R19.place_forget()
        self.R20.place_forget()
        self.R21.place_forget()
        self.R22.place_forget()
        self.R23.place_forget()
        self.R24.place_forget()
        self.btnR.place_forget()
        self.lblTitle.pack_forget()
        self.lblQ3.place_forget()
        
        if(self.var4.get()==self.name13):
            self.net+=2
        if(self.var4.get()==self.name14):
            self.a+=2
        if(self.var4.get()==self.name15):
            self.dis+=2
        if(self.var4.get()==self.name16):
            self.can+=2
        if(self.var5.get()==self.name17):
            self.net+=2
        if(self.var5.get()==self.name18):
            self.a+=2
        if(self.var5.get()==self.name19):
            self.dis+=2
        if(self.var5.get()==self.name20):
            self.can+=2
        if(self.var6.get()==self.name21):
            self.net+=2
        if(self.var6.get()==self.name22):
            self.a+=2
        if(self.var6.get()==self.name23):
            self.dis+=2
        if(self.var6.get()==self.name24):
            self.can+=2
        
        self.lblTitle2 = Label(self.newWindow3,text="La plateforme qui vous ressemble le mieux est:",font=("Arial",25,'bold','underline'),bg ='#A50021',fg='white')
        self.lblTitle2.place(x=300,y=200)
        
        self.plat=""
        
        if(self.net>=self.can):
            if(self.net>=self.a):
                if(self.net>=self.dis):
                    self.p = Label(self.newWindow3,text="NETFLIX",font=("Helvetica",55,'bold'),bg ='#A50021',fg='white')
                    self.p.place(x=500,y=400)
                else:
                    self.p = Label(self.newWindow3,text="DISNEY",font=("Helvetica",55,'bold'),bg ='#A50021',fg='white')
                    self.p.place(x=500,y=400)
            else:
                if(self.a>=self.dis):
                    self.p = Label(self.newWindow3,text="AMAZON",font=("Helvetica",55,'bold'),bg ='#A50021',fg='white')
                    self.p.place(x=500,y=400)
                else:
                    self.p = Label(self.newWindow3,text="DISNEY",font=("Helvetica",55,'bold'),bg ='#A50021',fg='white')
                    self.p.place(x=500,y=400)
        else:
            if(self.can>=self.a):
                if(self.can>=self.dis):
                    self.p = Label(self.newWindow3,text="CANAL",font=("Helvetica",55,'bold'),bg ='#A50021',fg='white')
                    self.p.place(x=500,y=400)
                else:
                    self.p = Label(self.newWindow3,text="DISNEY",font=("Helvetica",55,'bold'),bg ='#A50021',fg='white')
                    self.p.place(x=500,y=400)
            else:
                if(self.a>=self.dis):
                    self.p = Label(self.newWindow3,text="AMAZON",font=("Helvetica",55,'bold'),bg ='#A50021',fg='white')
                    self.p.place(x=500,y=400)
                else:
                    self.p = Label(self.newWindow3,text="DISNEY",font=("Helvetica",55,'bold'),bg ='#A50021',fg='white')
                    self.p.place(x=500,y=400)
                
            
        
        print(self.net)
        print(self.can)
        print(self.a)
        print(self.dis)
        #print(self.var2.get())
        #print(self.var3.get())   
        
        
        
from PIL import Image, ImageTk
        
            
window=Tk()
window.title("W2W")
window.geometry("1270x640+0+0")
window.configure(bg='#A50021')



image = Image.open("Page1.png")
photo = ImageTk.PhotoImage(image)
varun_label = Label(window,image=photo,bg='#A50021')
varun_label.place(x=300,y=200)



mywin=MonApp(window)
window.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/lib/python3.9/tkinter/__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "/var/folders/5g/3_n1b4wj6rd2cr07gfh2bv6w0000gn/T/ipykernel_25988/3113335884.py", line 303, in suivant
#     if (item in adn):
# NameError: name 'adn' is not defined
# Le Kernel s’est bloqué lors de l’exécution du code dans la cellule active ou une cellule précédente. Veuillez vérifier le code dans la ou les cellules pour identifier une cause possible de l’échec. Cliquez <a href='https://aka.ms/vscodeJupyterKernelCrash'>ici</a> pour plus d’informations. Pour plus d’informations, consultez Jupyter <a href='command:jupyter.viewOutput'>log</a>.
# Canceled future for execute_request message before replies were done
